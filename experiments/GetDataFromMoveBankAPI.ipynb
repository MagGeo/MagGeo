# %% [markdown]
# # To get the data from MoveBank API
#
#
# ![MoveBank Logo](https://www.movebank.org/cms/img/logo-movebank.png)
#
#
# To use this API, you need an account in Movebank, register in (https://www.movebank.org/), this code is based on https://github.com/movebank/movebank-api-doc/blob/master/mb_Meschenmoser.py
#
# Once you get the data for the study you are interested in, you can store into ./Data folder in MagGeo, to easy load it into the Sequential or Parallel notebooks.
#
# For more information about how to properly request the data using the MoveBank API, please visit (https://github.com/movebank/movebank-api-doc/blob/master/movebank-api.md). It is better for you to get familiar first with the way the data is requested, what attributes are avaliable and more importantly if the study you are looking for is open accesisable ( No username or pass is requiered) or you need to add your Movebank credentials to get access. You might also need to check what the API is returning checking the Individuals, Events and Studies URL requests.

# %% [markdown]
# The study and the data we are going to use in this example, is the following:
#
# >Nolet BA, Kölzsch A, Elderenbosch M, van Noordwijk AJ (2016) Scaring waterfowl as a management tool: how much more do geese forage after disturbance? Journal of Applied Ecology. doi:10.1111/1365-2664.12698

# %%
import requests
import os
import hashlib
import csv
import json
import io
from datetime import datetime, timedelta
from pandas import json_normalize
import pandas as pd

import geopandas as gpd
import movingpandas as mpd
from shapely.geometry import Point
import hvplot.pandas  # noqa

# %%
import getpass
movebank_username = getpass.getpass()

# %%
movebank_password = getpass.getpass()

# %%
def callMovebankAPI(params):
    # Requests Movebank API with ((param1, value1), (param2, value2),).
    # Assumes the environment variables 'mbus' (Movebank user name) and 'mbpw' (Movebank password).
    # Returns the API response as plain text.

    response = requests.get('https://www.movebank.org/movebank/service/direct-read', params=params, auth=(movebank_username, movebank_password))
    print("Request " + response.url)
    if response.status_code == 200:  # successful request
        if 'License Terms:' in str(response.content):
            # only the license terms are returned, hash and append them in a subsequent request.
            # See also
            # https://github.com/movebank/movebank-api-doc/blob/master/movebank-api.md#read-and-accept-license-terms-using-curl
            print("Has license terms")
            hash = hashlib.md5(response.content).hexdigest()
            params = params + (('license-md5', hash),)
            # also attach previous cookie:
            response = requests.get('https://www.movebank.org/movebank/service/direct-read', params=params,
                                    cookies=response.cookies, auth=(movebank_username, movebank_password))
            if response.status_code == 403:  # incorrect hash
                print("Incorrect hash")
                return ''
        return response.content.decode('utf-8')
    print(str(response.content))
    return ''


def getStudies():
    studies = callMovebankAPI((('entity_type', 'study'), ('i_can_see_data', 'true'), ('there_are_data_which_i_cannot_see', 'false')))
    if len(studies) > 0:
        # parse raw text to dicts
        studies = csv.DictReader(io.StringIO(studies), delimiter=',')
        return [s for s in studies if s['i_can_see_data'] == 'true' and s['there_are_data_which_i_cannot_see'] == 'false']
    return []


def getStudiesBySensor(studies, sensorname='GPS'):
    return [s for s in studies if sensorname in s['sensor_type_ids']]


def getIndividualsByStudy(study_id):
    individuals = callMovebankAPI((('entity_type', 'individual'), ('study_id', study_id)))
    if len(individuals) > 0:
        return list(csv.DictReader(io.StringIO(individuals), delimiter=','))
    return []


def prettyPrint(l):
    print(json.dumps(l, indent=2))

# %%
allstudies = getStudies()
# Out:
# Request https://www.movebank.org/movebank/service/direct-read?entity_type=study&i_can_see_data=true&there_are_data_which_i_cannot_see=false

# %%
gpsstudies = getStudiesBySensor(allstudies, 'GPS')
prettyPrint(gpsstudies)
# Out:
# [
#   {
#     "acknowledgements": "Work by Michael Kaatz and local collaborators",
#     "citation": "Experimental Great Bustard study",
#     "go_public_date": "",
#     "grants_used": "Funds from MPIAB covering the GSM tag.",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "7367444",
#     "is_test": "false",
#     "license_terms": "Please do not use data without contacting the PIs.",
#     "license_type": "CUSTOM",
#     "main_location_lat": "52.18",
#     "main_location_long": "12.685",
#     "name": "E-obs GSM Great Bustard",
#     "number_of_deployments": "1",
#     "number_of_individuals": "1",
#     "number_of_tags": "1",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "FV Gro\u00dftrappenschutz e.V. (Henrik Watzke)",
#     "study_objective": "Experimentally tracking great bustard in Germany.",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2012-08-30 09:15:46.001",
#     "timestamp_last_deployed_location": "2012-10-20 12:00:30.999",
#     "number_of_deployed_locations": "1929",
#     "taxon_ids": "Otis tarda",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "martin (Martin Wikelski)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1476751636",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "53.2230964003956",
#     "main_location_long": "23.1152343750002",
#     "name": "Montagu's Harrier Circus pygargus NE Poland",
#     "number_of_deployments": "5",
#     "number_of_individuals": "5",
#     "number_of_tags": "5",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "Mirski (Pawe\u0142 Mirski)",
#     "study_objective": "Montagu's Harrier adult males are tracked in NE Poland, both in agricultural landscape and in marshlands",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2019-07-29 10:03:01.000",
#     "timestamp_last_deployed_location": "2021-09-20 14:02:38.000",
#     "number_of_deployed_locations": "218613",
#     "taxon_ids": "Circus pygargus",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "Mirski (Pawe\u0142 Mirski)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "451547891",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "37.836364",
#     "main_location_long": "-122.493348",
#     "name": "TUVU Blue 368",
#     "number_of_deployments": "1",
#     "number_of_individuals": "1",
#     "number_of_tags": "1",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "GGRO (GGRO)",
#     "study_objective": "",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2018-01-19 00:33:08.000",
#     "timestamp_last_deployed_location": "2021-08-05 09:16:44.000",
#     "number_of_deployed_locations": "2502",
#     "taxon_ids": "Cathartes aura",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "GGRO (GGRO)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1131583309",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "31.2622938845376",
#     "main_location_long": "34.8017005917797",
#     "name": "BGU: Sandgrouse (Pterocles), Israel",
#     "number_of_deployments": "14",
#     "number_of_individuals": "14",
#     "number_of_tags": "14",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "elong (Elon Gur)",
#     "study_objective": "",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2015-06-02 12:10:00.000",
#     "timestamp_last_deployed_location": "2020-10-23 09:02:40.000",
#     "number_of_deployed_locations": "9629",
#     "taxon_ids": "Pterocles alchata,Pterocles senegallus",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "elong (Elon Gur)"
#   },
#   {
#     "acknowledgements": "MPIAB and BW Foundation",
#     "citation": "Wikelski et al. ",
#     "go_public_date": "",
#     "grants_used": "BW Foundation",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1470245419",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "47.6878327563108",
#     "main_location_long": "9.1424960655156",
#     "name": "Pet cat Germany MPIAB 2021",
#     "number_of_deployments": "8",
#     "number_of_individuals": "8",
#     "number_of_tags": "10",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "Georg Heine (Georg Heine)",
#     "study_objective": "Movement ecology of pet cats and protection of songbirds",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2021-04-21 18:59:55.000",
#     "timestamp_last_deployed_location": "2021-06-27 07:16:06.000",
#     "number_of_deployed_locations": "267875",
#     "taxon_ids": "Felis catus",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "Georg Heine (Georg Heine)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "240931758",
#     "is_test": "false",
#     "license_terms": "Data are for use as part of NASA's Arctic-Boreal Vulnerability Experiment (ABoVE). Please contact the PI to discuss proposed uses.",
#     "license_type": "CUSTOM",
#     "main_location_lat": "39.717",
#     "main_location_long": "-105.132",
#     "name": "ABoVE: USFWS R6 Golden Eagles",
#     "number_of_deployments": "2",
#     "number_of_individuals": "2",
#     "number_of_tags": "2",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "bwsmith533 (Brian W Smith)",
#     "study_objective": "This study is participating in the Arctic Animal Movement Archive (AAMA).",
#     "study_type": "research",
#     "suspend_license_terms": "true",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2014-05-15 01:00:00.000",
#     "timestamp_last_deployed_location": "2019-05-01 20:00:00.000",
#     "number_of_deployed_locations": "33983",
#     "taxon_ids": "Aquila chrysaetos",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "bwsmith533 (Brian W Smith)"
#   },
#   {
#     "acknowledgements": "Craighead Beringia South",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "212420825",
#     "is_test": "false",
#     "license_terms": "Not to be used without written permission.",
#     "license_type": "CUSTOM",
#     "main_location_lat": "45.7981695301727",
#     "main_location_long": "-110.3466796875",
#     "name": "Beringia South Migrant Golden Eagle",
#     "number_of_deployments": "1",
#     "number_of_individuals": "1",
#     "number_of_tags": "1",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "rcran910 (Ross Crandall)",
#     "study_objective": "This study is participating in the Arctic Animal Movement Archive (AAMA).",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2012-05-09 18:00:00.000",
#     "timestamp_last_deployed_location": "2015-07-27 23:00:00.000",
#     "number_of_deployed_locations": "8659",
#     "taxon_ids": "Aquila chrysaetos",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "rcran910 (Ross Crandall)"
#   },
#   {
#     "acknowledgements": "MPIAB",
#     "citation": "MPIAB ICARUS Hawkwatch",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1700206712",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "40.4531",
#     "main_location_long": "-111.4531",
#     "name": "ICARUS HawkWatch International",
#     "number_of_deployments": "",
#     "number_of_individuals": "",
#     "number_of_tags": "10",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "martin (Martin Wikelski)",
#     "study_objective": "ICARUS Hawkwatch",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "",
#     "timestamp_last_deployed_location": "",
#     "number_of_deployed_locations": "",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS,Accessory Measurements",
#     "contact_person_name": "HWI_LTMCS (HWI LTMCS)"
#   },
#   {
#     "acknowledgements": "all credits due to Michael Abedi-Lartey, Dina Dechmann and Jakob Fahr",
#     "citation": "Calder\u00f3n-Capote MC, Dechmann DKN, Fahr J, Wikelski M, Kays R, O\u2019Mara MT. 2020. Foraging movements are density-independent among straw-coloured fruit bats. R Soc Open Sci. 7(5). https://doi.org/10.1098/rsos.200274.",
#     "go_public_date": "",
#     "grants_used": "Max Planck Society",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "14352599",
#     "is_test": "false",
#     "license_terms": "use of data only permitted after obtaining license from PIs (MPIAB)",
#     "license_type": "CUSTOM",
#     "main_location_lat": "12.3976198230989",
#     "main_location_long": "-1.48896932601929",
#     "name": "Eidolon helvum; Burkina Faso, Ouagadougou; wet season 2013 [eobs 1Hz]",
#     "number_of_deployments": "1",
#     "number_of_individuals": "1",
#     "number_of_tags": "1",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "abedilartey (Michael Abedi-Lartey)",
#     "study_objective": "African straw-coloured fruit bat",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2013-08-10 04:59:20.998",
#     "timestamp_last_deployed_location": "2013-08-10 08:26:11.998",
#     "number_of_deployed_locations": "9170",
#     "taxon_ids": "Eidolon helvum",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "abedilartey (Michael Abedi-Lartey)"
#   },
#   {
#     "acknowledgements": "This research was conducted in partnership with National Geographic Society, the Wildlife Institute of India, the Indian Institute of Technology, WildTeam Bangladesh, the University of Dhaka, and the Isabela Foundation, with approval from all relevant agencies of the Governments of India and Bangladesh. We also wish to thank the communities at each expedition site along the Ganges and our support teams, Felis Creations and Green Holidays. The technology for this project was developed by the Arribada Initiative ",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "the Sea to Source: Ganges Expedition run and funded by the  National Geographic Society ",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1271155477",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "22.194190025872",
#     "main_location_long": "90.9045374393421",
#     "name": "Plastic bottle tracking ",
#     "number_of_deployments": "",
#     "number_of_individuals": "22",
#     "number_of_tags": "22",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "ed291 (Emily Duncan )",
#     "study_objective": "A proof of concept study by applying open source tracking technology (previously used on marine vertebrates) aiming to track and map the movement of plastics litter items (bottles) through aquatic systems",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "",
#     "timestamp_last_deployed_location": "",
#     "number_of_deployed_locations": "",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "ed291 (Emily Duncan )"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1340039045",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "-38.51",
#     "main_location_long": "145.15",
#     "name": "Little penguin 2020, Phillip Island, Australia",
#     "number_of_deployments": "43",
#     "number_of_individuals": "43",
#     "number_of_tags": "16",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "achiaradia@penguins.org.au (Andre Chiaradia)",
#     "study_objective": "Breeding little penguins are tracked by AxyTrek. Depth and acceleration data exist. ",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2020-09-16 21:19:56.000",
#     "timestamp_last_deployed_location": "2020-10-16 10:00:21.000",
#     "number_of_deployed_locations": "41185",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "akikato (Akiko KATO)"
#   },
#   {
#     "acknowledgements": "MPIAB",
#     "citation": "Navedo, Wikelski et al. ",
#     "go_public_date": "",
#     "grants_used": "MPIAB",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1393831579",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "-41.8733964442476",
#     "main_location_long": "-73.7628467456143",
#     "name": "ICARUS Hudsonian Godwit Chile",
#     "number_of_deployments": "10",
#     "number_of_individuals": "10",
#     "number_of_tags": "10",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "martin (Martin Wikelski)",
#     "study_objective": "Movement of Limosa haemastica",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2021-01-08 21:49:00.000",
#     "timestamp_last_deployed_location": "2021-08-26 03:28:00.000",
#     "number_of_deployed_locations": "1131",
#     "taxon_ids": "Limosa haemastica",
#     "sensor_type_ids": "GPS,Accessory Measurements",
#     "contact_person_name": "martin (Martin Wikelski)"
#   },
#   {
#     "acknowledgements": "Raptor View Research Institute",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "5009273",
#     "is_test": "false",
#     "license_terms": "Data not to be used for any purpose without written permission.",
#     "license_type": "CUSTOM",
#     "main_location_lat": "46.9802523552188",
#     "main_location_long": "-112.5",
#     "name": "Adult Golden Eagle Satellite Tracking",
#     "number_of_deployments": "25",
#     "number_of_individuals": "25",
#     "number_of_tags": "25",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "RVRI (Raptor View Research Inst.)",
#     "study_objective": "This study is participating in the Arctic Animal Movement Archive (AAMA).",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2007-03-30 01:38:27.000",
#     "timestamp_last_deployed_location": "2021-09-11 20:00:12.000",
#     "number_of_deployed_locations": "200371",
#     "taxon_ids": "Aquila chrysaetos",
#     "sensor_type_ids": "GPS,Argos Doppler Shift,Accessory Measurements",
#     "contact_person_name": "RVRI (Raptor View Research Inst.)"
#   },
#   {
#     "acknowledgements": "MNHN and MPIAB",
#     "citation": "MNHN and MPIAB",
#     "go_public_date": "",
#     "grants_used": "MNHN and MPIAB",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1542206798",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "48.4807463553287",
#     "main_location_long": "2.38554564183487",
#     "name": "ICARUS Cuckoo Fred Jiguet [ID PROG_1189]",
#     "number_of_deployments": "5",
#     "number_of_individuals": "5",
#     "number_of_tags": "7",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "frederic.jiguet (JIGUET Fr\u00e9d\u00e9ric)",
#     "study_objective": "",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2021-05-28 12:01:00.000",
#     "timestamp_last_deployed_location": "2021-09-19 03:05:00.000",
#     "number_of_deployed_locations": "485",
#     "taxon_ids": "Cuculus canorus",
#     "sensor_type_ids": "GPS,Accessory Measurements",
#     "contact_person_name": "frederic.jiguet (JIGUET Fr\u00e9d\u00e9ric)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "2026-05-01 03:00:00.000",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1490219581",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "49.623267189151",
#     "main_location_long": "-64.326882362366",
#     "name": "Atlantic Eiders - GSM",
#     "number_of_deployments": "23",
#     "number_of_individuals": "23",
#     "number_of_tags": "44",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "ScottGilliland (Scott Gilliland)",
#     "study_objective": "",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2021-04-28 15:06:59.000",
#     "timestamp_last_deployed_location": "2021-09-01 12:11:27.000",
#     "number_of_deployed_locations": "28412",
#     "taxon_ids": "Somateria mollissima",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "ScottGilliland (Scott Gilliland)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "2022-12-31 23:00:00.000",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1294989952",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "53.4782392614832",
#     "main_location_long": "6.16333007812404",
#     "name": "Domestic cat roaming behavior on Schiermonnikoog",
#     "number_of_deployments": "14",
#     "number_of_individuals": "14",
#     "number_of_tags": "14",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "J.J. Lamfers (Jagua Jay Lamfers)",
#     "study_objective": "",
#     "study_type": "research",
#     "suspend_license_terms": "true",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2020-06-02 22:51:30.000",
#     "timestamp_last_deployed_location": "2020-07-02 12:55:14.000",
#     "number_of_deployed_locations": "17594",
#     "taxon_ids": "Felis catus",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "J.J. Lamfers (Jagua Jay Lamfers)"
#   },
#   {
#     "acknowledgements": "All credits due to Dina Dechmann, Jakob Fahr, Martin Wikelski and Michael Abedi-Lartey",
#     "citation": "Calder\u00f3n-Capote MC, Dechmann DKN, Fahr J, Wikelski M, Kays R, O\u2019Mara MT. 2020. Foraging movements are density-independent among straw-coloured fruit bats. R Soc Open Sci. 7(5). https://doi.org/10.1098/rsos.200274.",
#     "go_public_date": "",
#     "grants_used": "Max Planck Society",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "32430844",
#     "is_test": "false",
#     "license_terms": "Use of data only permitted after obtaining license from PIs (MPIAB)",
#     "license_type": "CUSTOM",
#     "main_location_lat": "12.3978320157247",
#     "main_location_long": "-1.48920267820358",
#     "name": "Eidolon helvum; Burkina Faso, Ouagadougou; wet season 2014 [eobs]",
#     "number_of_deployments": "9",
#     "number_of_individuals": "9",
#     "number_of_tags": "9",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "abedilartey (Michael Abedi-Lartey)",
#     "study_objective": "African straw-coloured fruit bat",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2014-06-17 19:27:41.001",
#     "timestamp_last_deployed_location": "2014-06-24 06:00:26.999",
#     "number_of_deployed_locations": "2013",
#     "taxon_ids": "Eidolon helvum",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "abedilartey (Michael Abedi-Lartey)"
#   },
#   {
#     "acknowledgements": "Thanks for help: ECCD, GNPS",
#     "citation": "Cruz S, Proa\u00f1o CB, Anderson D, Huyvaert K, Wikelski M. 2013. Data from: The Environmental-Data Automated Track Annotation (Env-DATA) System: Linking animal tracks with environmental data. Movebank Data Repository. <a href=\"https://www.doi.org/10.5441/001/1.3hp3s250\" target=\"_blank\">https://www.doi.org/10.5441/001/1.3hp3s250</a><br><br>Dodge S, Bohrer G, Weinzierl R, Davidson SC, Kays R, Douglas D, Cruz S, Han J, Brandes D, Wikelski M. 2013. The Environmental-Data Automated Track Annotation (Env-DATA) System\u2014linking animal tracks with environmental data. Movement Ecology 1:3. https://doi.org/10.1186/2051-3933-1-3",
#     "go_public_date": "",
#     "grants_used": "NSF and Max Planck",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "2911040",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "-1.39",
#     "main_location_long": "-89.62",
#     "name": "Galapagos Albatrosses",
#     "number_of_deployments": "28",
#     "number_of_individuals": "28",
#     "number_of_tags": "28",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "martin (Martin Wikelski)",
#     "study_objective": "Tracking of Galapagos albatrosses for conservation and basic science. Waved albatrosses were tracked during breeding and non-breeding periods between 2008 and 2010.",
#     "study_type": "research",
#     "suspend_license_terms": "true",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2008-05-31 13:29:31.998",
#     "timestamp_last_deployed_location": "2008-11-06 18:00:55.998",
#     "number_of_deployed_locations": "16028",
#     "taxon_ids": "Phoebastria irrorata",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "sebas (Sebastian M. Cruz)"
#   },
#   {
#     "acknowledgements": "Project SNOWstorm is a collaboration of many individuals passionate about raptor research and Snowy Owl conservation.  A current list of participants can be found on the Project SNOWstorm web site.  Project SNOWstorm would not be possible without the many hours of effort contributed by the members of Project SNOWstorm and many other unnamed individuals.  We appreciate all of the contributions these diverse individuals have made to this collaboration.\n  ",
#     "citation": "Brinker, D. F., Weidensaul, C.S., Huy, J. S. & Therrien J.F. [year].  Project SNOWstorm, collaborative study of Snowy Owl (Bubo scandiacus) movements in North America.  Hosted by the Ned Smith Center for Nature and Art, Millersburg, Pennsylvania, USA. www.ProjectSNOWstorm.org, accessed on [date].",
#     "go_public_date": "",
#     "grants_used": "Project SNOWstorm has been funded by a diversity of contributors, including many small donations made by generous contributors to crowd funding campaigns, from bird clubs, and other sources.  For a current list of major contributors please refer to the Project SNOWstorm web page.\n  ",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1112099901",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "40.5361",
#     "main_location_long": "-76.926",
#     "name": "Project SNOWstorm (Snowy Owl Movements)",
#     "number_of_deployments": "95",
#     "number_of_individuals": "92",
#     "number_of_tags": "92",
#     "principal_investigator_address": "Ned Smith Center For Nature and Art,\n176 Water Company Road\nMillersburg, PA 17061\n  ",
#     "principal_investigator_email": "dfbrinker@verizon.net",
#     "principal_investigator_name": "Project SNOWstorm",
#     "study_objective": "Project SNOWstorm focuses primarily on Snowy Owl winter movements in the U.S. and southern Canada.  Significant movements to and from the Arctic are also documented as well as summer movement data.  We encourage users of these data to contact the data owners to answer any questions you may have regarding the data and proposed uses. \n  ",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2013-12-18 11:26:39.000",
#     "timestamp_last_deployed_location": "2021-09-19 08:03:27.000",
#     "number_of_deployed_locations": "510683",
#     "taxon_ids": "Bubo scandiacus",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "contact_person_name": "David Brinker (David F. Brinker)"
#   },
#   {
#     "acknowledgements": "Nicola Palmer",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "NA",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1268085753",
#     "is_test": "false",
#     "license_terms": "This license lets others distribute, remix, tweak, and build upon your work, even commercially, as long as they credit you for the original creation.",
#     "license_type": "CC_BY",
#     "main_location_lat": "-31.66888",
#     "main_location_long": "116.16469",
#     "name": "BfRw Petrogale lateralis",
#     "number_of_deployments": "5",
#     "number_of_individuals": "5",
#     "number_of_tags": "5",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "Spicospina (Michael Smith)",
#     "study_objective": "Radio tracking of Black-flanked Rock-wallabies at AWC Paruna Wildlife Sanctuary",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2019-08-17 00:01:00.000",
#     "timestamp_last_deployed_location": "2019-12-20 06:40:33.000",
#     "number_of_deployed_locations": "15470",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "Spicospina (Michael Smith)"
#   },
#   {
#     "acknowledgements": "Collaborative study Max Planck - Parque Nactional Isla de Contoy",
#     "citation": "MPIAB-PNIC collaboration study",
#     "go_public_date": "",
#     "grants_used": "MPIAB and St Thomas Productions",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "7367511",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "21.4530686330868",
#     "main_location_long": "-86.66015625",
#     "name": "E-obs GSM PNIC MPIAB Frigate birds in hurricanes",
#     "number_of_deployments": "2",
#     "number_of_individuals": "2",
#     "number_of_tags": "3",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "martin (Martin Wikelski)",
#     "study_objective": "Understand movements of frigate birds in hurricanes",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2012-09-18 00:01:22.999",
#     "timestamp_last_deployed_location": "2017-05-25 00:30:56.000",
#     "number_of_deployed_locations": "3979",
#     "taxon_ids": "Fregata magnificens",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "wolfheid (Wolfgang Heidrich)"
#   },
#   {
#     "acknowledgements": "St. Martins Lodge, Austria",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "522309921",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "47.7741321944568",
#     "main_location_long": "16.8792975930173",
#     "name": "Common Shelduck Tadorna tadorna Austria",
#     "number_of_deployments": "5",
#     "number_of_individuals": "5",
#     "number_of_tags": "2",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "lkhil (Leander Khil)",
#     "study_objective": "Common Shelducks tagged in Neusiedler See-Seewinkel National Park by Leander Khil",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2018-07-05 01:26:05.000",
#     "timestamp_last_deployed_location": "2021-09-07 18:06:21.000",
#     "number_of_deployed_locations": "32088",
#     "taxon_ids": "Tadorna tadorna",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "lkhil (Leander Khil)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "783305786",
#     "is_test": "false",
#     "license_terms": "Data may be used for non-commercial educational purposes. Contact the PIs for collaboration on publication in professional journals or books. These data and associated metadata have been partially reviewed for accuracy and completeness but represent \u201clive-feed\u201d data from active projects.  As such, data is intended for use by cooperators and for general summaries only until QA/QC procedures are completed and should not be considered \u201canalysis ready\u201d.  No warranty expressed or implied is made regarding the display or utility of the data on any other system or for general or scientific purposes, nor shall the act of distribution constitute any such warranty. Any use of trade, firm, or product names is for descriptive purposes only and does not imply endorsement by the U.S. Government.",
#     "license_type": "CUSTOM",
#     "main_location_lat": "38.4531365812567",
#     "main_location_long": "-121.819401103999",
#     "name": "2019 Female ducks",
#     "number_of_deployments": "209",
#     "number_of_individuals": "209",
#     "number_of_tags": "520",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "Suisun Marsh Waterfowl Project (Cory Overton)",
#     "study_objective": "Data includes all locations from marked hens March 1, 2019 onward.  for nest identification.",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2019-03-01 00:00:00.000",
#     "timestamp_last_deployed_location": "2066-11-30 23:37:36.000",
#     "number_of_deployed_locations": "556482",
#     "taxon_ids": "Anas platyrhynchos,Anas strepera,Anas acuta,Anas discors,Anas cyanoptera,Anas americana,Anas clypeata,Aythya valisineria,Aythya marila",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "Suisun Marsh Waterfowl Project (Cory Overton)"
#   },
#   {
#     "acknowledgements": "Max Planck Institute of Animal Behavior and Landesbund f\u00fcr Vogelschutz.",
#     "citation": "Fiedler W, Leppelsack E, Leppelsack H, Stahl T, Wieding O, Wikelski M. 2019. Data from: Study \"LifeTrack White Stork Bavaria\" (2014-2019). Movebank Data Repository. <a href=\"https://www.doi.org/10.5441/001/1.v1cs4nn0\" target=\"_blank\">https://www.doi.org/10.5441/001/1.v1cs4nn0</a> <br><br>Cheng Y, Fiedler W, Wikelski M, Flack A. 2019. \"Closer-to-home\" strategy benefits juvenile survival in a long-distance migratory bird. Ecology and Evolution. 9(16): 8945\u20138952. https://doi.org/10.1002/ece3.5395",
#     "go_public_date": "",
#     "grants_used": "We thank Gerhard und Ellen Zeidler Foundation (Bad Waldkraiburg) for financial support in the season 2014.",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "24442409",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_BY",
#     "main_location_lat": "49.8353252629665",
#     "main_location_long": "10.8242797851562",
#     "name": "LifeTrack White Stork Bavaria",
#     "number_of_deployments": "47",
#     "number_of_individuals": "47",
#     "number_of_tags": "77",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "myotis (Wolfgang Fiedler)",
#     "study_objective": "Determining migration routes of White Storks in Eurasia. Lifetime tracking of storks. Effects of migration strategies on survival and fitness. Involvement of the public",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2014-06-23 07:05:08.000",
#     "timestamp_last_deployed_location": "2021-09-17 15:20:23.000",
#     "number_of_deployed_locations": "4548780",
#     "taxon_ids": "Ciconia ciconia",
#     "sensor_type_ids": "GPS,Acceleration,Magnetometer,Orientation",
#     "contact_person_name": "myotis (Wolfgang Fiedler)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1208033562",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "52.475394106925",
#     "main_location_long": "19.7901199548514",
#     "name": "Larus canus",
#     "number_of_deployments": "",
#     "number_of_individuals": "",
#     "number_of_tags": "552",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "marfaber (Marcin)",
#     "study_objective": "",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "",
#     "timestamp_last_deployed_location": "",
#     "number_of_deployed_locations": "",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "marfaber (Marcin)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "92261778",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_BY",
#     "main_location_lat": "56.9550170231644",
#     "main_location_long": "24.1185015812516",
#     "name": "LifeTrack Whooper Swan Latvia",
#     "number_of_deployments": "9",
#     "number_of_individuals": "9",
#     "number_of_tags": "16",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "Dmitrijs Boiko (Dmitrijs Boiko)",
#     "study_objective": "This study is participating in the Arctic Animal Movement Archive (AAMA).",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2015-07-25 09:22:53.000",
#     "timestamp_last_deployed_location": "2017-05-28 12:00:07.000",
#     "number_of_deployed_locations": "76706",
#     "taxon_ids": "Cygnus cygnus",
#     "sensor_type_ids": "GPS,Acceleration,Accessory Measurements,Magnetometer",
#     "contact_person_name": "myotis (Wolfgang Fiedler)"
#   },
#   {
#     "acknowledgements": "all credits due to Michael Abedi-Lartey, Dina Dechmann and Jakob Fahr",
#     "citation": "Max Planck Society",
#     "go_public_date": "",
#     "grants_used": "Max Planck Society",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "18668412",
#     "is_test": "false",
#     "license_terms": "Use of data only permitted after obtaining license from PIs (MPIAB)",
#     "license_type": "CUSTOM",
#     "main_location_lat": "6.23488661362057",
#     "main_location_long": "-0.393733384553343",
#     "name": "Eidolon helvum; Ghana, Kibi; dry season 2014 [Fleetronics]",
#     "number_of_deployments": "7",
#     "number_of_individuals": "7",
#     "number_of_tags": "7",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "abedilartey (Michael Abedi-Lartey)",
#     "study_objective": "African straw-coloured fruit bat",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2014-02-06 22:31:41.000",
#     "timestamp_last_deployed_location": "2014-04-05 23:40:00.000",
#     "number_of_deployed_locations": "549",
#     "taxon_ids": "Eidolon helvum",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "abedilartey (Michael Abedi-Lartey)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "206418248",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "47.8092348740236",
#     "main_location_long": "13.9492034912109",
#     "name": "Corvus corax, Common Raven - Eastern Alps",
#     "number_of_deployments": "107",
#     "number_of_individuals": "105",
#     "number_of_tags": "103",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "mclo (Matthias Loretto)",
#     "study_objective": "",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2017-07-19 14:33:17.000",
#     "timestamp_last_deployed_location": "2070-11-30 10:24:06.000",
#     "number_of_deployed_locations": "4386242",
#     "taxon_ids": "Corvus corax",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "mclo (Matthias Loretto)"
#   },
#   {
#     "acknowledgements": "MPIAB and NIOO and others",
#     "citation": "MPIAB and NIOO and others",
#     "go_public_date": "",
#     "grants_used": "MPIAB and NIOO and others",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1542106029",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "47.5704149898198",
#     "main_location_long": "7.57601146737708",
#     "name": "ICARUS Starling navigation",
#     "number_of_deployments": "6",
#     "number_of_individuals": "6",
#     "number_of_tags": "6",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "MorrisonPot (Morrison Pot)",
#     "study_objective": "Understand the Perdeck experiment",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2021-05-09 23:07:00.000",
#     "timestamp_last_deployed_location": "2021-09-16 22:05:00.000",
#     "number_of_deployed_locations": "210",
#     "taxon_ids": "Sturnus vulgaris",
#     "sensor_type_ids": "GPS,Accessory Measurements",
#     "contact_person_name": "MorrisonPot (Morrison Pot)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "Koks B, Schlaich A, Schaub T, Klaassen R, Anselin A, Desmet P, Milotic T, Janssens K, Bouten W (2019) H_GRONINGEN - Western marsh harriers (Circus aeruginosus, Accipitridae) breeding in Groningen (the Netherlands). Dataset. https://doi.org/10.5281/zenodo.3552507",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "922263102",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "53.278",
#     "main_location_long": "6.981",
#     "name": "H_GRONINGEN - Western marsh harriers (Circus aeruginosus, Accipitridae) breeding in Groningen (the Netherlands)",
#     "number_of_deployments": "4",
#     "number_of_individuals": "4",
#     "number_of_tags": "4",
#     "principal_investigator_address": "Grauwe kiekendief - Kenniscentrum Akkervogels (GKA), Postbus 46, 9679 ZG Scheemda, Netherlands",
#     "principal_investigator_email": "info@grauwekiekendief.nl",
#     "principal_investigator_name": "Almut Schlaich & Tonio Schaub",
#     "study_objective": "H_GRONINGEN - Western marsh harriers (Circus aeruginosus, Accipitridae) breeding in Groningen (the Netherlands) is a bird tracking dataset collected by the Grauwe kiekendief - Kenniscentrum Akkervogels (GKA) / Dutch Montagu\u2019s Harrier Foundation and published by the Research Institute for Nature and Forest (INBO). It contains animal tracking data collected for the project/study H_GRONINGEN, using trackers developed by the University of Amsterdam Bird Tracking System (UvA-BiTS, http://www.uva-bits.nl). The study was operational from 2012 until 2018. In total 4 individuals of Western marsh harriers (Circus aeruginosus) have been tagged in their breeding area in the province Groningen (the Netherlands) close to the Netherlands-Germany border, mainly to study their habitat use and migration behaviour. Data from active or new trackers are periodically uploaded from the UvA-BiTS database to Movebank (see https://github.com/inbo/bird-tracking) and then Zenodo, but for this study none of the tracked birds have been observed in the vicinity of their known breeding grounds (and thus data retrieval points) since 2018. See Milotic et al. (2020, https://doi.org/10.3897/zookeys.947.52570) for a more detailed description of this dataset.",
#     "study_type": "research",
#     "suspend_license_terms": "true",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2012-05-10 17:47:49.000",
#     "timestamp_last_deployed_location": "2018-07-11 11:10:40.000",
#     "number_of_deployed_locations": "987117",
#     "taxon_ids": "Circus aeruginosus",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "milotictanja (Tanja Milotic)"
#   },
#   {
#     "acknowledgements": "Giant Armadillo Conservation Project ",
#     "citation": "not set",
#     "go_public_date": "",
#     "grants_used": "Giant Armadillo Conservation Project Collaborators ",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1217893648",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "-19.270437",
#     "main_location_long": "-55.788412",
#     "name": "Myrmecophaga tridactyla Pantanal",
#     "number_of_deployments": "14",
#     "number_of_individuals": "14",
#     "number_of_tags": "14",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "Arnaud Desbiez (Arnaud Desbiez)",
#     "study_objective": "not set",
#     "study_type": "research",
#     "suspend_license_terms": "true",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2013-07-26 04:00:05.000",
#     "timestamp_last_deployed_location": "2017-08-12 19:40:06.000",
#     "number_of_deployed_locations": "204005",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "aline.giroux (Aline da Silva Giroux)"
#   },
#   {
#     "acknowledgements": "all credits due to Michael Abedi-Lartey, Dina Dechmann and Jakob Fahr",
#     "citation": "Max Planck Society",
#     "go_public_date": "",
#     "grants_used": "Max Planck Society",
#     "has_quota": "true",
#     "i_am_owner": "false",
# ...
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2016-04-19 00:12:00.000",
#     "timestamp_last_deployed_location": "2016-05-15 23:01:04.000",
#     "number_of_deployed_locations": "13522",
#     "taxon_ids": "Pteropus lylei",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "Julien_Cappelle (Julien Cappelle)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "Irvine LM, Winsor MH, Follett TM, Mate BR, Palacios DM (2020)  An at-sea assessment of Argos location accuracy for three species of large whales, and the effect of deep-diving behavior on location error. Animal Biotelemetry  8, 20. doi:10.1186/s40317-020-00207-x.",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "15661938",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_BY",
#     "main_location_lat": "28.0",
#     "main_location_long": "-88.0",
#     "name": "Sperm whales Gulf of Mexico 2011-2013 - Fastloc GPS data",
#     "number_of_deployments": "18",
#     "number_of_individuals": "17",
#     "number_of_tags": "18",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "dpalacios (Daniel Palacios)",
#     "study_objective": "Argos-linked archival tags with Fastloc GPS were deployed on free-ranging sperm (Physeter macrocephalus), blue (Balaenoptera musculus), and fin whales (B. physalus) to derive empirical estimates of Argos location errors for these species, examine possible behavior-related differences, and test the effect of incorporating species-specific error parameters on performance of a commonly used movement model. Argos location errors for blue and fin whale tags were similar and were combined (n = 1,712 locations) for comparison against sperm whale tags (n = 1,206 locations). Location error magnitudes for tags attached to sperm whales were significantly larger than blue/fin whale tags for almost all Argos location classes (LC), ranging from 964 m versus 647 m for LC 3, respectively, to 10,569 m versus 5,589 m for LC B, respectively. However, these differences were not seen while tags floated at the surface after release. Sperm whale tags were significantly colder than ambient temperature when surfacing from a dive, compared to blue/fin whale tags (16.9\u00b0C versus 1.3\u00b0C, respectively) leading to larger changes in tag temperature during post-dive intervals. The increased rate of tag temperature change while at the surface was correlated to increased error magnitude for sperm whale tags but not blue/fin whale tags. Movement model output was not significantly improved by incorporating species-specific error parameters. Location accuracy estimates for blue/fin whales were within the range estimated for other marine megafauna, but were higher for sperm whales. Thermal inertia from deep, long-duration dives likely caused transmission frequency drift and greater Argos location error in sperm whales, as tags warmed at the surface during post-dive intervals. Thus, tracks of deep-diving species may be less reliable than for other species. However, differences in calculated error magnitude were less than the typical scales of movement and had limited effect on movement model output. Therefore, broad-scale interpretation of Argos tracking data will likely be unaffected, although fine-scale interpretation should be made with more caution for deep-diving species inhabiting warm regions.",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2011-07-10 23:16:00.000",
#     "timestamp_last_deployed_location": "2013-08-21 19:22:23.000",
#     "number_of_deployed_locations": "7151",
#     "taxon_ids": "Physeter macrocephalus",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "tomasf (Tomas)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "OFB Study",
#     "go_public_date": "",
#     "grants_used": "FEDER, OFB (French Office of Biodiversity)",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1099486001",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "46.556971695641",
#     "main_location_long": "-1.78510665893551",
#     "name": "Pintail in Olonne Marsh (France)",
#     "number_of_deployments": "",
#     "number_of_individuals": "",
#     "number_of_tags": "20",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "",
#     "study_objective": "Selection of habitats in winter",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "",
#     "timestamp_last_deployed_location": "",
#     "number_of_deployed_locations": "",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "JOYEUX (Emmanuel)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1105192033",
#     "is_test": "false",
#     "license_terms": "Data are being prepared for publication in the Movebank Data Repository. Contact the owner to discuss use. ",
#     "license_type": "CUSTOM",
#     "main_location_lat": "82.92",
#     "main_location_long": "24.6333",
#     "name": "Sea turtle state space modeling results from tagging sites in Florida and the Gulf of Mexico",
#     "number_of_deployments": "234",
#     "number_of_individuals": "278",
#     "number_of_tags": "277",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "robertskelsey (Kelsey Roberts)",
#     "study_objective": "This dataset incorporates satellite tracks from 235 marine turtles across an 11 year tagging effort. There are 3 species in this dataset - loggerhead (Caretta caretta), green (Chelonia mydas) and hawksbill (Eretmochelys imbricata). Using this data, we developed a model using step selection analysis to quantify sea turtle habitat use within the study area, specifically as it relates to marine protected area boundaries. We are providing the summary information from the state space modeling (SSM), not the raw tracking data. When gaps of many days occur in the raw data, the resulting track becomes less informed by data and thus less reliable the longer the gap is. Thus, we split individual tracks with gaps longer than 25 days, and we passed these tracks to the SSM as if they were separate individuals. This resulted in 278 tracks from 235 individual turtles. ",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2008-05-19 22:12:00.000",
#     "timestamp_last_deployed_location": "2019-03-10 15:43:07.000",
#     "number_of_deployed_locations": "37922",
#     "taxon_ids": "Caretta caretta,Chelonia mydas,Eretmochelys imbricata",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "robertskelsey (Kelsey Roberts)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "Rapha\u00ebl Musseau & Christophe Barbraud",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "247772625",
#     "is_test": "false",
#     "license_terms": "Please contact Rapha\u00ebl Musseau to download and use the data. www.raphaelmusseau.wordpress.com",
#     "license_type": "CUSTOM",
#     "main_location_lat": "45.4762710421405",
#     "main_location_long": "-0.797549366405492",
#     "name": "CIGOGNES DE SAINTONGE",
#     "number_of_deployments": "9",
#     "number_of_individuals": "9",
#     "number_of_tags": "25",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "Raphael Musseau (Raphael Musseau)",
#     "study_objective": "Project dedicated to the study of home range and migration of White Storks breeding in the marshes of the Gironde estuary",
#     "study_type": "research",
#     "suspend_license_terms": "true",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2019-06-21 13:56:32.000",
#     "timestamp_last_deployed_location": "2021-09-18 11:13:54.000",
#     "number_of_deployed_locations": "1905410",
#     "taxon_ids": "Ciconia ciconia",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "Raphael Musseau (Raphael Musseau)"
#   },
#   {
#     "acknowledgements": "Data provided by Tom Akre, Donald J. Brown, Madaline M. Cochrane, Nandintsetseg Dejid, Vickie DeNicola, Chris S. DePerno, Jonathan Dresher-Lehman, Nicholas P. Gould, Jack Hollins, Hiroaki Ishii, Yayoi Kaneko, Todd E. Katzner, Shaun Killen, Barbara Koeck, Sergio A. Lambertucci, Scott D. LaPoint, E. Patricia Medici, Bernd-U. Meyburg, Tricia A. Miller, Ron A. Moen, Thomas Mueller, Thomas Pfeiffer, Alexandre Roulin, Kamran Safi, Anne K. Scharf, Robin S\u00e9chaud, Jared A. Stabach, Koji Yamazaki",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1092737859",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_BY",
#     "main_location_lat": "0.0",
#     "main_location_long": "0.0",
#     "name": "GPS calibration data (global)",
#     "number_of_deployments": "233",
#     "number_of_individuals": "233",
#     "number_of_tags": "190",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "hfleming (Chris H. Fleming)",
#     "study_objective": "ATS G2110e, ATS G5, ATS G10 UltraLITE, CTT 1090, CTT BT3, CTT ES400, e-obs 1059-7106, Lotek Lifecycle 330, Lotek PinPoint 240, Lotek WildCell, NTT Docomo CTG-001G, Ornitella 182902-191779, Sirtrack Pinnacle Solar G5C275F, Technosmart GiPSy 5, TS Quantum 4000 Enhanced, Telonics Gen 4, Vectronic GPS Plus, Vectronic Vertex Lite-3D, Vemco HR2-V9",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2009-08-13 14:57:38.000",
#     "timestamp_last_deployed_location": "2019-10-06 07:55:00.000",
#     "number_of_deployed_locations": "4579494",
#     "taxon_ids": "",
#     "sensor_type_ids": "GPS",
#     "contact_person_name": "hfleming (Chris H. Fleming)"
#   },
#   {
#     "acknowledgements": "This dataset was collected using infrastructure provided by INBO and funded by Research Foundation - Flanders (FWO) as part of the Belgian contribution to LifeWatch. Part of the tags were funded by the Sovon Dutch Centre for Field Ornithology.",
#     "citation": "Spanoghe G, Desmet P, Milotic T, Van Ryckegem G, Vanoverbeke J, Ens BJ, Bouten W (2019) O_WESTERSCHELDE - Eurasian oystercatchers (Haematopus ostralegus, Haematopodidae) breeding in East Flanders (Belgium). Dataset. https://doi.org/10.5281/zenodo.3734898",
#     "go_public_date": "",
#     "grants_used": "Research Foundation - Flanders (FWO) & Sovon Dutch Centre for Field Ornithology",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "1099562810",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CC_0",
#     "main_location_lat": "51.275",
#     "main_location_long": "4.205",
#     "name": "O_WESTERSCHELDE - Eurasian oystercatchers (Haematopus ostralegus, Haematopodidae) breeding in East Flanders (Belgium)",
#     "number_of_deployments": "13",
#     "number_of_individuals": "13",
#     "number_of_tags": "13",
#     "principal_investigator_address": "Research Institute for Nature and Forest (INBO), Havenlaan 88/73, 1000 Brussels, Belgium",
#     "principal_investigator_email": "geert.spanoghe@inbo.be",
#     "principal_investigator_name": "Geert Spanoghe",
#     "study_objective": "O_WESTERSCHELDE - Eurasian oystercatchers (Haematopus ostralegus, Haematopodidae) breeding in East Flanders (Belgium) is a bird tracking dataset published by the Research Institute for Nature and Forest (INBO). It contains animal tracking data collected by the LifeWatch GPS tracking network for large birds (http://lifewatch.be/en/gps-tracking-network-large-birds) for the project/study O_WESTERSCHELDE, using trackers developed by the University of Amsterdam Bird Tracking System (UvA-BiTS, http://www.uva-bits.nl). The study has been operational since 2018. In total 13 individuals of Eurasian oystercatchers (Haematopus ostralegus) have been tagged in their breeding area in East Flanders (Belgium), west of the river Scheldt, mainly to study their habitat use on mudflats of the Western Scheldt (the Netherlands). Data from active or new trackers are periodically uploaded from the UvA-BiTS database to Movebank (see https://github.com/inbo/bird-tracking) and then Zenodo.",
#     "study_type": "research",
#     "suspend_license_terms": "true",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "true",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2018-05-24 18:10:51.000",
#     "timestamp_last_deployed_location": "2020-04-11 16:47:40.000",
#     "number_of_deployed_locations": "73047",
#     "taxon_ids": "Haematopus ostralegus",
#     "sensor_type_ids": "GPS,Acceleration",
#     "contact_person_name": "milotictanja (Tanja Milotic)"
#   },
#   {
#     "acknowledgements": "",
#     "citation": "",
#     "go_public_date": "",
#     "grants_used": "",
#     "has_quota": "true",
#     "i_am_owner": "false",
#     "id": "452845647",
#     "is_test": "false",
#     "license_terms": "",
#     "license_type": "CUSTOM",
#     "main_location_lat": "37.0902398030722",
#     "main_location_long": "-109.072265624995",
#     "name": "USFWS Nat'l Raptor Research - rehab'd eagle survival",
#     "number_of_deployments": "11",
#     "number_of_individuals": "11",
#     "number_of_tags": "13",
#     "principal_investigator_address": "",
#     "principal_investigator_email": "",
#     "principal_investigator_name": "FWSRaptors (Brian Millsap)",
#     "study_objective": "Study objective: estimate post-release survival rates of eagles that have received veterinary care and specialized after-care husbandry to recover from otherwise likely fatal injury or disease.",
#     "study_type": "research",
#     "suspend_license_terms": "false",
#     "i_can_see_data": "true",
#     "there_are_data_which_i_cannot_see": "false",
#     "i_have_download_access": "false",
#     "i_am_collaborator": "false",
#     "study_permission": "na",
#     "timestamp_first_deployed_location": "2013-04-28 20:00:00.000",
#     "timestamp_last_deployed_location": "2021-09-14 12:51:41.000",
#     "number_of_deployed_locations": "21043",
#     "taxon_ids": "Aquila ,Aquila chrysaetos",
#     "sensor_type_ids": "GPS,Argos Doppler Shift,Accessory Measurements",
#     "contact_person_name": "bcr16goegsu (Bob Murphy)"
#   }
# ]

# %%
individuals = getIndividualsByStudy(study_id=133992043) 
# Using the readme of https://www.datarepository.movebank.org/handle/10255/move.546 you can get the study ID

prettyPrint(individuals)
# Out:
# Request https://www.movebank.org/movebank/service/direct-read?entity_type=individual&study_id=133992043
# [
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936193",
#     "latest_date_born": "",
#     "local_identifier": "2704",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-09-30 08:30:48.000",
#     "timestamp_end": "2014-04-01 18:00:56.000",
#     "number_of_events": "706",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936196",
#     "latest_date_born": "",
#     "local_identifier": "2711",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-29 13:30:44.000",
#     "timestamp_end": "2013-10-15 08:30:50.000",
#     "number_of_events": "54",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936199",
#     "latest_date_born": "",
#     "local_identifier": "2731",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-02-16 18:00:50.000",
#     "timestamp_end": "2014-10-25 08:30:44.000",
#     "number_of_events": "3947",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936202",
#     "latest_date_born": "",
#     "local_identifier": "2753",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-09-11 10:40:31.000",
#     "timestamp_end": "2014-05-13 18:01:39.000",
#     "number_of_events": "688",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992717",
#     "latest_date_born": "",
#     "local_identifier": "3067",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-31 08:20:07.000",
#     "timestamp_end": "2014-04-21 01:00:06.000",
#     "number_of_events": "4155",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936205",
#     "latest_date_born": "",
#     "local_identifier": "3079",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-09-10 04:41:02.000",
#     "timestamp_end": "2014-04-11 11:30:25.000",
#     "number_of_events": "625",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992683",
#     "latest_date_born": "",
#     "local_identifier": "3084",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-30 14:00:06.000",
#     "timestamp_end": "2014-07-06 21:00:06.000",
#     "number_of_events": "6421",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992720",
#     "latest_date_born": "",
#     "local_identifier": "3088",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-09-08 04:40:06.000",
#     "timestamp_end": "2014-05-02 07:40:45.000",
#     "number_of_events": "2958",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936208",
#     "latest_date_born": "",
#     "local_identifier": "3089",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-28 18:00:41.000",
#     "timestamp_end": "2013-09-29 18:20:06.000",
#     "number_of_events": "223",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992686",
#     "latest_date_born": "",
#     "local_identifier": "3097",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-29 09:40:06.000",
#     "timestamp_end": "2014-06-05 08:20:06.000",
#     "number_of_events": "8398",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992723",
#     "latest_date_born": "",
#     "local_identifier": "3098",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-30 13:00:06.000",
#     "timestamp_end": "2014-05-12 06:30:25.000",
#     "number_of_events": "2881",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936211",
#     "latest_date_born": "",
#     "local_identifier": "3101",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-09-10 05:21:02.000",
#     "timestamp_end": "2013-10-19 04:40:46.000",
#     "number_of_events": "353",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992726",
#     "latest_date_born": "",
#     "local_identifier": "3103",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-29 18:00:41.000",
#     "timestamp_end": "2013-10-02 06:40:47.000",
#     "number_of_events": "993",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992690",
#     "latest_date_born": "",
#     "local_identifier": "3104",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-14 15:30:06.000",
#     "timestamp_end": "2014-10-01 17:30:07.000",
#     "number_of_events": "6058",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936265",
#     "latest_date_born": "",
#     "local_identifier": "3267",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-19 22:00:25.000",
#     "timestamp_end": "2014-06-11 20:00:54.000",
#     "number_of_events": "529",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992693",
#     "latest_date_born": "",
#     "local_identifier": "3271",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-19 23:00:07.000",
#     "timestamp_end": "2014-10-24 09:30:06.000",
#     "number_of_events": "6584",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936268",
#     "latest_date_born": "",
#     "local_identifier": "3276",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-19 18:00:06.000",
#     "timestamp_end": "2014-06-06 10:30:25.000",
#     "number_of_events": "2815",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936217",
#     "latest_date_born": "",
#     "local_identifier": "62348",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2006-04-03 17:00:00.000",
#     "timestamp_end": "2006-05-27 11:00:00.000",
#     "number_of_events": "470",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992600",
#     "latest_date_born": "",
#     "local_identifier": "62350",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2006-03-22 05:00:00.000",
#     "timestamp_end": "2006-10-31 18:00:00.000",
#     "number_of_events": "1134",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936221",
#     "latest_date_born": "",
#     "local_identifier": "62351",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2006-03-21 17:00:00.000",
#     "timestamp_end": "2006-05-30 08:00:00.000",
#     "number_of_events": "346",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992644",
#     "latest_date_born": "",
#     "local_identifier": "700",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-19 00:02:44.000",
#     "timestamp_end": "2014-10-04 11:54:20.000",
#     "number_of_events": "3142",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992647",
#     "latest_date_born": "",
#     "local_identifier": "701",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-28 00:53:59.000",
#     "timestamp_end": "2014-05-31 16:35:38.000",
#     "number_of_events": "225",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992650",
#     "latest_date_born": "",
#     "local_identifier": "707",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-30 09:58:12.000",
#     "timestamp_end": "2014-05-30 13:19:02.000",
#     "number_of_events": "1097",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992653",
#     "latest_date_born": "",
#     "local_identifier": "709",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-14 20:20:31.000",
#     "timestamp_end": "2014-10-02 20:02:08.000",
#     "number_of_events": "2180",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936271",
#     "latest_date_born": "",
#     "local_identifier": "711",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-13 12:30:36.000",
#     "timestamp_end": "2014-06-15 23:08:08.000",
#     "number_of_events": "112",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992656",
#     "latest_date_born": "",
#     "local_identifier": "712",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-09 14:41:05.000",
#     "timestamp_end": "2014-10-04 13:26:47.000",
#     "number_of_events": "3172",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992659",
#     "latest_date_born": "",
#     "local_identifier": "716",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-28 10:29:09.000",
#     "timestamp_end": "2014-05-31 03:33:26.000",
#     "number_of_events": "867",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992662",
#     "latest_date_born": "",
#     "local_identifier": "720",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-02-09 07:20:30.000",
#     "timestamp_end": "2014-10-02 09:00:51.000",
#     "number_of_events": "979",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936225",
#     "latest_date_born": "",
#     "local_identifier": "72363",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-06 00:53:00.000",
#     "timestamp_end": "2007-05-06 14:00:00.000",
#     "number_of_events": "184",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992608",
#     "latest_date_born": "",
#     "local_identifier": "72364",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-28 18:00:00.000",
#     "timestamp_end": "2007-10-20 09:00:00.000",
#     "number_of_events": "550",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936229",
#     "latest_date_born": "",
#     "local_identifier": "72411",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-05 19:28:00.000",
#     "timestamp_end": "2007-04-03 09:00:00.000",
#     "number_of_events": "45",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992611",
#     "latest_date_born": "",
#     "local_identifier": "72413",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-03 18:00:00.000",
#     "timestamp_end": "2007-10-20 10:00:00.000",
#     "number_of_events": "716",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936234",
#     "latest_date_born": "",
#     "local_identifier": "72414",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-16 14:00:00.000",
#     "timestamp_end": "2007-04-01 05:00:00.000",
#     "number_of_events": "53",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936238",
#     "latest_date_born": "",
#     "local_identifier": "72415",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-29 14:00:00.000",
#     "timestamp_end": "2007-05-20 02:00:00.000",
#     "number_of_events": "238",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992614",
#     "latest_date_born": "",
#     "local_identifier": "72416",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-28 18:00:00.000",
#     "timestamp_end": "2007-09-22 11:00:00.000",
#     "number_of_events": "468",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992617",
#     "latest_date_born": "",
#     "local_identifier": "72417",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-28 18:00:00.000",
#     "timestamp_end": "2007-10-30 18:41:00.000",
#     "number_of_events": "579",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992665",
#     "latest_date_born": "",
#     "local_identifier": "727",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-25 07:20:56.000",
#     "timestamp_end": "2014-05-30 12:55:28.000",
#     "number_of_events": "1656",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992696",
#     "latest_date_born": "",
#     "local_identifier": "728",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-14 17:00:58.000",
#     "timestamp_end": "2014-10-03 13:16:37.000",
#     "number_of_events": "463",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936186",
#     "latest_date_born": "",
#     "local_identifier": "730",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-29 19:38:10.000",
#     "timestamp_end": "2013-10-02 19:00:22.000",
#     "number_of_events": "291",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992620",
#     "latest_date_born": "",
#     "local_identifier": "73052",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-12 11:53:00.000",
#     "timestamp_end": "2007-10-06 09:00:00.000",
#     "number_of_events": "422",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992623",
#     "latest_date_born": "",
#     "local_identifier": "73053",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-28 18:00:00.000",
#     "timestamp_end": "2007-12-03 00:52:00.000",
#     "number_of_events": "886",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992626",
#     "latest_date_born": "",
#     "local_identifier": "73054",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-02 18:00:00.000",
#     "timestamp_end": "2007-07-06 00:00:00.000",
#     "number_of_events": "723",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936243",
#     "latest_date_born": "",
#     "local_identifier": "73055",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2007-03-01 18:00:00.000",
#     "timestamp_end": "2007-03-21 05:00:00.000",
#     "number_of_events": "43",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992699",
#     "latest_date_born": "",
#     "local_identifier": "733",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-31 22:02:08.000",
#     "timestamp_end": "2013-10-01 23:47:40.000",
#     "number_of_events": "183",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936214",
#     "latest_date_born": "",
#     "local_identifier": "734",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-17 15:10:15.000",
#     "timestamp_end": "2014-10-05 03:57:48.000",
#     "number_of_events": "119",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992702",
#     "latest_date_born": "",
#     "local_identifier": "736",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-29 08:22:39.000",
#     "timestamp_end": "2013-10-01 11:16:10.000",
#     "number_of_events": "564",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992668",
#     "latest_date_born": "",
#     "local_identifier": "738",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-18 11:15:02.000",
#     "timestamp_end": "2014-10-02 11:26:38.000",
#     "number_of_events": "717",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992671",
#     "latest_date_born": "",
#     "local_identifier": "742",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-20 00:28:34.000",
#     "timestamp_end": "2014-10-03 09:01:43.000",
#     "number_of_events": "995",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992705",
#     "latest_date_born": "",
#     "local_identifier": "744",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-29 12:39:10.000",
#     "timestamp_end": "2013-09-30 15:59:40.000",
#     "number_of_events": "2507",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992708",
#     "latest_date_born": "",
#     "local_identifier": "746",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-30 13:06:38.000",
#     "timestamp_end": "2013-09-29 23:03:16.000",
#     "number_of_events": "402",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992674",
#     "latest_date_born": "",
#     "local_identifier": "749",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-19 05:40:26.000",
#     "timestamp_end": "2014-10-06 18:24:56.000",
#     "number_of_events": "231",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936190",
#     "latest_date_born": "",
#     "local_identifier": "750",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-08-29 14:28:47.000",
#     "timestamp_end": "2014-10-02 13:31:08.000",
#     "number_of_events": "60",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992677",
#     "latest_date_born": "",
#     "local_identifier": "762",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-13 05:33:15.000",
#     "timestamp_end": "2014-10-19 09:04:02.000",
#     "number_of_events": "672",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992711",
#     "latest_date_born": "",
#     "local_identifier": "764",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-08-29 03:22:14.000",
#     "timestamp_end": "2013-09-29 18:49:08.000",
#     "number_of_events": "723",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992714",
#     "latest_date_born": "",
#     "local_identifier": "767",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2013-09-05 18:33:37.000",
#     "timestamp_end": "2013-09-30 07:18:07.000",
#     "number_of_events": "112",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992680",
#     "latest_date_born": "",
#     "local_identifier": "768",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "f",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2014-03-17 11:30:20.000",
#     "timestamp_end": "2014-10-01 17:53:48.000",
#     "number_of_events": "1871",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992629",
#     "latest_date_born": "",
#     "local_identifier": "79689",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2008-03-21 17:18:00.000",
#     "timestamp_end": "2008-06-23 02:00:00.000",
#     "number_of_events": "437",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936248",
#     "latest_date_born": "",
#     "local_identifier": "79690",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2009-02-28 02:27:00.000",
#     "timestamp_end": "2009-03-17 16:00:00.000",
#     "number_of_events": "11",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936252",
#     "latest_date_born": "",
#     "local_identifier": "79691",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2008-03-17 17:00:00.000",
#     "timestamp_end": "2008-04-25 04:00:00.000",
#     "number_of_events": "122",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936256",
#     "latest_date_born": "",
#     "local_identifier": "79692",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2008-03-04 17:00:00.000",
#     "timestamp_end": "2008-04-29 10:00:00.000",
#     "number_of_events": "154",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "138936260",
#     "latest_date_born": "",
#     "local_identifier": "79693",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2008-03-19 17:00:00.000",
#     "timestamp_end": "2008-03-31 15:54:00.000",
#     "number_of_events": "13",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992632",
#     "latest_date_born": "",
#     "local_identifier": "79694",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2008-03-27 17:00:00.000",
#     "timestamp_end": "2008-12-09 13:00:00.000",
#     "number_of_events": "640",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992635",
#     "latest_date_born": "",
#     "local_identifier": "79695",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2008-02-28 07:00:00.000",
#     "timestamp_end": "2008-09-11 13:03:00.000",
#     "number_of_events": "397",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992638",
#     "latest_date_born": "",
#     "local_identifier": "79696",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2008-03-12 17:00:00.000",
#     "timestamp_end": "2008-09-29 12:00:00.000",
#     "number_of_events": "542",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   },
#   {
#     "comments": "",
#     "death_comments": "",
#     "earliest_date_born": "",
#     "exact_date_of_birth": "",
#     "id": "133992641",
#     "latest_date_born": "",
#     "local_identifier": "79698",
#     "nick_name": "",
#     "ring_id": "",
#     "sex": "m",
#     "taxon_canonical_name": "Anser albifrons",
#     "timestamp_start": "2009-03-29 17:00:00.000",
#     "timestamp_end": "2009-10-14 11:00:00.000",
#     "number_of_events": "500",
#     "number_of_deployments": "1",
#     "sensor_type_ids": "GPS,Argos Doppler Shift",
#     "taxon_detail": ""
#   }
# ]

# %%
STUDY_ID = 133992043
INDIVIDUAL_ID = '138936193'

# %%
params = (('entity_type', 'event'), ('study_id', STUDY_ID), ('individual_id', INDIVIDUAL_ID), ('sensor_type_id', 653))
events_csv = callMovebankAPI(params)
# Out:
# Request https://www.movebank.org/movebank/service/direct-read?entity_type=event&study_id=133992043&individual_id=138936193&sensor_type_id=653

# %%
df = pd.read_csv(io.StringIO(events_csv))
df
# Out:
#                    timestamp  location_lat  location_long  individual_id  \
# 0    2013-09-30 08:30:48.000     62.707029      36.132815      138936193
# 1    2013-09-30 13:31:26.000     60.148437      32.238147      138936193
# 2    2013-10-02 08:30:43.000     54.331167      12.581129      138936193
# 3    2014-03-17 22:00:13.000     52.108574       6.217192      138936193
# 4    2014-03-17 22:30:28.000     52.194110       6.505170      138936193
# ..                       ...           ...            ...            ...
# 701  2014-04-01 13:31:22.000     52.326469      39.370952      138936193
# 702  2014-04-01 14:01:06.000     52.326355      39.370578      138936193
# 703  2014-04-01 14:31:21.000     52.326355      39.370580      138936193
# 704  2014-04-01 15:01:16.000     52.326334      39.370876      138936193
# 705  2014-04-01 18:00:56.000     52.325375      39.372300      138936193
#
#         tag_id
# 0    138936194
# 1    138936194
# 2    138936194
# 3    138936194
# 4    138936194
# ..         ...
# 701  138936194
# 702  138936194
# 703  138936194
# 704  138936194
# 705  138936194
#
# [706 rows x 5 columns]

# %%
export_csv = df.to_csv (r"../data/MoveBank.csv", index = None, header=True)
# Save the Movebank data from the API, to the Data folder in MagGeo

# %%
emp_df = pd.read_csv(r"../data/MoveBank.csv")

# %% [markdown]
# ## Let's Map the data we just got from MoveBank API
#
# To map the data we can use geopandas (https://geopandas.org/), Hvplot(https://hvplot.holoviz.org/) and moving pandas (https://anitagraser.github.io/movingpandas/) to get a nice and interactive tool to explore the data we are looking at.

# %%
df.dropna(subset=['location_long', 'location_lat'], inplace=True)

# %%
gdf = gpd.GeoDataFrame(
    df.drop(['location_long', 'location_lat'], axis=1),
    crs='epsg:4326',
    geometry=[Point(xy) for xy in zip(df.location_long, df.location_lat)])

# %%
gdf
# Out:
#                    timestamp  individual_id     tag_id  \
# 0    2013-09-30 08:30:48.000      138936193  138936194
# 1    2013-09-30 13:31:26.000      138936193  138936194
# 2    2013-10-02 08:30:43.000      138936193  138936194
# 3    2014-03-17 22:00:13.000      138936193  138936194
# 4    2014-03-17 22:30:28.000      138936193  138936194
# ..                       ...            ...        ...
# 701  2014-04-01 13:31:22.000      138936193  138936194
# 702  2014-04-01 14:01:06.000      138936193  138936194
# 703  2014-04-01 14:31:21.000      138936193  138936194
# 704  2014-04-01 15:01:16.000      138936193  138936194
# 705  2014-04-01 18:00:56.000      138936193  138936194
#
#                       geometry
# 0    POINT (36.13282 62.70703)
# 1    POINT (32.23815 60.14844)
# 2    POINT (12.58113 54.33117)
# 3     POINT (6.21719 52.10857)
# 4     POINT (6.50517 52.19411)
# ..                         ...
# 701  POINT (39.37095 52.32647)
# 702  POINT (39.37058 52.32636)
# 703  POINT (39.37058 52.32635)
# 704  POINT (39.37088 52.32633)
# 705  POINT (39.37230 52.32538)
#
# [706 rows x 4 columns]

# %%
gdf.hvplot(title=f'Movebank events of individual {INDIVIDUAL_ID}',
           geo=True,
           tiles='CartoLight',
           frame_width=700,
           frame_height=500)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]

# %% [markdown]
# ### Using Moving Pandas we could map the trajectory based on the GPS points.

# %%
gdf['timestamp'] = pd.to_datetime(gdf['timestamp'])
gdf.set_index('timestamp', inplace=True)

# %%
traj = mpd.Trajectory(gdf, 'tag_id')

# %%
traj.hvplot(title=f'Trajectory of individual {INDIVIDUAL_ID}',
            c='tag_id',
            frame_width=700,
            frame_height=500,
            line_width=7.0,
            tiles='CartoLight',
            cmap='Viridis',
            colorbar=True)
# Out:
# :Overlay
#    .Tiles.I :Tiles   [x,y]
#    .Path.I  :Path   [Longitude,Latitude]   (tag_id)

# %% [markdown]
# Of course if you get more attributes from the MoveBack API request you migth plot differente attrubutes, but the process is similar from what we've done.
